# %%
import csv 
import pandas as pd

with open('Data/2015.tsv','r') as tsv:
    data = [line.strip().split('\t') for line in tsv]
    
col_names = data[0]
df = pd.DataFrame(data, columns=col_names)
df = df[1:]

#open code_sex.csv and convert it to a DataFrame
with open('Data/code_sex.csv','r') as csv:
    sex_descrip = [line.strip().split(',') for line in csv]

sex_header = sex_descrip[0]
df_sex = pd.DataFrame(sex_descrip, columns=sex_header)
df_sex = df_sex[1:]
indexed_df_sex = df_sex.set_index('Code')

#open code_body_part.csv and convert it to a DataFrame
with open('Data/code_body_part.csv','r') as csv:
    body_part_descrip = [line.strip().split(',') for line in csv]

body_part_header = body_part_descrip[0]
df_body_part = pd.DataFrame(body_part_descrip, columns=body_part_header)
df_body_part = df_body_part[1:]
indexed_df_body_part = df_body_part.set_index('Code')

#open code_diagnosis.csv and convert it to a DataFrame
with open('Data/code_diagnosis.csv','r') as csv:
    diagnosis_descrip = [line.strip().split(',') for line in csv]

diagnosis_header = diagnosis_descrip[0]
df_diagnosis = pd.DataFrame(diagnosis_descrip, columns=diagnosis_header)
df_diagnosis = df_diagnosis[1:]
indexed_df_diagnosis = df_diagnosis.set_index('Code')

#open code_disposition.csv and convert it to a DataFrame
with open('Data/code_disposition.csv','r') as csv:
    disposition_descrip = [line.strip().split(',') for line in csv]

disposition_header = disposition_descrip[0]
df_disposition = pd.DataFrame(disposition_descrip, columns=disposition_header)
df_disposition = df_disposition[1:]
indexed_df_disposition = df_disposition.set_index('Code')

#open code_fire.csv and convert it to a DataFrame
with open('Data/code_fire.csv','r') as csv:
    fire_descrip = [line.strip().split(',') for line in csv]

fire_header = fire_descrip[0]
df_fire = pd.DataFrame(fire_descrip, columns=fire_header)
df_fire = df_fire[1:]
indexed_df_fire = df_fire.set_index('Code')

#open code_locale.csv and convert it to a DataFrame
with open('Data/code_locale.csv','r') as csv:
    locale_descrip = [line.strip().split(',') for line in csv]

locale_header = locale_descrip[0]
df_locale = pd.DataFrame(locale_descrip, columns=locale_header)
df_locale = df_locale[1:]
indexed_df_locale = df_locale.set_index('Code')

#open code_product.csv and convert it to a DataFrame
with open('Data/code_product.csv','r') as csv:
    product_descrip = [line.strip().split(',',1) for line in csv]

product_header = product_descrip[0]
df_product = pd.DataFrame(product_descrip, columns=product_header)
df_product = df_product[1:]
indexed_df_product = df_product.set_index('Code')

#open code_race.csv and convert it to a DataFrame
with open('Data/code_race.csv','r') as csv:
    race_descrip = [line.strip().split(',') for line in csv]

race_header = race_descrip[0]
df_race = pd.DataFrame(race_descrip, columns=race_header)
df_race = df_race[1:]
indexed_df_race = df_race.set_index('Code')

#merge all the codes
df['sex_descrip']=df.sex.map(indexed_df_sex.Description)
df['body_part_descrip']=df.body_part.map(indexed_df_body_part.Description)
df['diag_descrip']=df.diag.map(indexed_df_diagnosis.Description)
df['disposition_descrip']=df.disposition.map(indexed_df_disposition.Description)
df['fire_descrip']=df.fmv.map(indexed_df_fire.Description)
df['locale_descrip']=df.location.map(indexed_df_locale.Description)
df['product1_descrip']=df.prod1.map(indexed_df_product.Description)
df['product2_descrip']=df.prod2.map(indexed_df_product.Description)
df['race_descrip']=df.race.map(indexed_df_race.Description)

#combine the 2 narr fields into 1
df['Notes'] = df['narr1'].map(str) + df['narr2']

df1 = df[['CPSC Case #', 
         'trmt_date', 
         'psu', 
         'weight', 
         'age', 
         'sex_descrip', 
         'race_descrip',
         'body_part_descrip', 
         'diag_descrip', 
         'disposition_descrip', 
         'fire_descrip', 
         'locale_descrip', 
         'product1_descrip', 
         'product2_descrip', 
         'Notes']]

# %%
df1
# Out:
#        CPSC Case #   trmt_date psu   weight  age sex_descrip race_descrip  \
# 1        150733174  07/11/2015  38  15.7762    5        MALE      UNKNOWN
# 2        150734723  07/06/2015  43  83.2157   36        MALE        WHITE
# 3        150817487  08/02/2015  51  74.8813   20      FEMALE      UNKNOWN
# 4        150717776  06/26/2015  41  15.7762   61        MALE      UNKNOWN
# 5        150721694  07/04/2015  42  74.8813   88      FEMALE        OTHER
# 6        150721815  07/02/2015  32   5.6748  216      FEMALE        WHITE
# 7        150713483  06/08/2015  93  15.7762   25        MALE        BLACK
# 8        150704114  06/14/2015  56  83.2157   53        MALE        WHITE
# 9        150736558  07/16/2015  70  83.2157   98        MALE        BLACK
# 10       150734928  07/13/2015  51  74.8813   48      FEMALE        BLACK
# 11       150734952  07/04/2015  57  15.7762   20        MALE        BLACK
# 12       150821622  07/20/2015  43  83.2157   20      FEMALE        WHITE
# 13       150713631  07/04/2015  67  15.7762   11        MALE      UNKNOWN
# 14       150666343  06/27/2015  95  15.7762   26      FEMALE        WHITE
# 15       150748843  07/16/2015   5  37.6645   33        MALE          NaN
# 16       150655986  06/06/2015  96  83.2157   36        MALE      UNKNOWN
# 17       150901411  08/27/2015   4  83.2157   65      FEMALE        WHITE
# 18       150844598  07/26/2015   8   5.6748    2        MALE        BLACK
# 19       150960076  09/19/2015  95  15.7762   69      FEMALE        WHITE
# 20       150970927  09/26/2015  24  97.9239  204      FEMALE        WHITE
# 21       150942430  09/09/2015  95  15.7762   47      FEMALE        WHITE
# 22       150956275  09/07/2015  68  97.9239   16        MALE        WHITE
# 23       150944645  09/14/2015  58  15.7762   31        MALE      UNKNOWN
# 24       151028950  09/05/2015  77  15.7762    7        MALE      UNKNOWN
# 25       151029050  09/05/2015  14  49.2646   27      FEMALE      UNKNOWN
# 26       151005625  09/28/2015  51  74.8813  209      FEMALE        WHITE
# 27       151005691  09/29/2015  51  74.8813   27      FEMALE        BLACK
# 28       150913230  09/04/2015   2  15.7762   39        MALE      UNKNOWN
# 29       150964576  09/19/2015  37   5.6748  207        MALE      UNKNOWN
# 30       150971068  09/22/2015  42  74.8813   14        MALE        WHITE
# ...            ...         ...  ..      ...  ...         ...          ...
# 359100   150603931  05/19/2015  67  15.0591    4        MALE      UNKNOWN
# 359101   150725804  07/08/2015  78  97.9239   33      FEMALE        BLACK
# 359102   150702215  06/27/2015  21  15.7762   51      FEMALE      UNKNOWN
# 359103   151124313  11/01/2015  79  85.7374    3        MALE        WHITE
# 359104   151124428  11/02/2015  68  97.9239   21      FEMALE        WHITE
# 359105   151115064  11/04/2015  73  85.7374   12      FEMALE      UNKNOWN
# 359106   151100368  10/28/2015  73  83.2157   85      FEMALE      UNKNOWN
# 359107   150639249  06/08/2015  33  15.7762    4        MALE        WHITE
# 359108   150639257  06/08/2015  33  15.7762    5      FEMALE        WHITE
# 359109   150630000  05/20/2015  16  97.9239    5      FEMALE        BLACK
# 359110   150528367  01/13/2015  14  49.2646   85      FEMALE      UNKNOWN
# 359111   150528459  05/12/2015  21  15.0591   12      FEMALE      UNKNOWN
# 359112   150619154  05/13/2015  26  15.0591   27        MALE        OTHER
# 359113   150554802  05/15/2015  31   5.6748   15        MALE        BLACK
# 359114   150643117  05/31/2015  90   5.6748  201        MALE        WHITE
# 359115   150607827  05/27/2015  32   5.6748  218        MALE        WHITE
# 359116   150600190  05/28/2015  73  80.8381    5        MALE      UNKNOWN
# 359117   150648619  06/17/2015  95  15.7762   52      FEMALE        WHITE
# 359118   150640832  06/08/2015  67  15.7762    8      FEMALE      UNKNOWN
# 359119   150633445  05/31/2015  50  74.8813  220      FEMALE      UNKNOWN
# 359120   150633526  04/04/2015  14  49.2646   51      FEMALE      UNKNOWN
# 359121   150628863  06/08/2015  95  15.7762   30      FEMALE        WHITE
# 359122   150607637  05/22/2015  32   5.6748  215      FEMALE        BLACK
# 359123   150747209  07/24/2015  73  83.2157   14      FEMALE      UNKNOWN
# 359124   150747217  07/24/2015  73  83.2157    2        MALE      UNKNOWN
# 359125   150739278  05/31/2015  23  15.0591    7        MALE      UNKNOWN
# 359126   150733393  07/11/2015  18   5.6748    3      FEMALE        BLACK
# 359127   150819286  07/24/2015  21  15.7762   38        MALE      UNKNOWN
# 359128   150823002  08/08/2015  78  97.9239   38      FEMALE        WHITE
# 359129   150723074  06/20/2015  54  49.2646    5      FEMALE        WHITE
#
#        body_part_descrip         diag_descrip   disposition_descrip  \
# 1              LOWER ARM             FRACTURE  TREATED AND RELEASED
# 2                  WRIST             FRACTURE  TREATED AND RELEASED
# 3                    EAR                OTHER  TREATED AND RELEASED
# 4                   KNEE                OTHER  TREATED AND RELEASED
# 5                   HEAD      INTERNAL INJURY  TREATED AND RELEASED
# 6                   FACE                OTHER  TREATED AND RELEASED
# 7              LOWER ARM        BURNS THERMAL          HOSPITALIZED
# 8               SHOULDER             FRACTURE  TREATED AND RELEASED
# 9                   FACE           LACERATION  TREATED AND RELEASED
# 10           LOWER TRUNK  CONTUSIONS ABRASION  TREATED AND RELEASED
# 11                  HAND           LACERATION  TREATED AND RELEASED
# 12             LOWER LEG             FRACTURE  TREATED AND RELEASED
# 13                 MOUTH        DENTAL INJURY  TREATED AND RELEASED
# 14                  HEAD      INTERNAL INJURY  TREATED AND RELEASED
# 15                   TOE  CONTUSIONS ABRASION  TREATED AND RELEASED
# 16                  HAND           LACERATION  TREATED AND RELEASED
# 17                  FOOT           LACERATION  TREATED AND RELEASED
# 18                FINGER             FRACTURE  TREATED AND RELEASED
# 19           LOWER TRUNK        STRAIN SPRAIN  TREATED AND RELEASED
# 20                  FACE           LACERATION  TREATED AND RELEASED
# 21           LOWER TRUNK        STRAIN SPRAIN  TREATED AND RELEASED
# 22                  KNEE           LACERATION          HOSPITALIZED
# 23                  HEAD             HEMATOMA  TREATED AND RELEASED
# 24                 WRIST             FRACTURE  TREATED AND RELEASED
# 25                  FACE             HEMATOMA  TREATED AND RELEASED
# 26                  HEAD             HEMATOMA  TREATED AND RELEASED
# 27                   TOE        STRAIN SPRAIN  TREATED AND RELEASED
# 28                   EAR                OTHER  TREATED AND RELEASED
# 29                  HEAD      INTERNAL INJURY          HOSPITALIZED
# 30           UPPER TRUNK        STRAIN SPRAIN  TREATED AND RELEASED
# ...                  ...                  ...                   ...
# 359100             MOUTH        DENTAL INJURY  TREATED AND RELEASED
# 359101               EAR                OTHER  TREATED AND RELEASED
# 359102              FOOT  CONTUSIONS ABRASION  TREATED AND RELEASED
# 359103             MOUTH           LACERATION  TREATED AND RELEASED
# 359104       LOWER TRUNK        STRAIN SPRAIN  TREATED AND RELEASED
# 359105             ANKLE        STRAIN SPRAIN  TREATED AND RELEASED
# 359106         UPPER ARM             FRACTURE          HOSPITALIZED
# 359107              HEAD           LACERATION  TREATED AND RELEASED
# 359108              FACE             FRACTURE           TRANSFERRED
# 359109               EAR           LACERATION  TREATED AND RELEASED
# 359110       LOWER TRUNK             FRACTURE  HELD FOR OBSERVATION
# 359111            FINGER           LACERATION  TREATED AND RELEASED
# 359112         LOWER ARM           LACERATION  TREATED AND RELEASED
# 359113             ANKLE        STRAIN SPRAIN  TREATED AND RELEASED
# 359114              HEAD      INTERNAL INJURY  TREATED AND RELEASED
# 359115         LOWER LEG                OTHER  TREATED AND RELEASED
# 359116               EAR         FOREIGN BODY  TREATED AND RELEASED
# 359117          SHOULDER        STRAIN SPRAIN  TREATED AND RELEASED
# 359118             ELBOW        STRAIN SPRAIN  TREATED AND RELEASED
# 359119    ALL PARTS BODY            POISONING  TREATED AND RELEASED
# 359120            FINGER         FOREIGN BODY  TREATED AND RELEASED
# 359121       LOWER TRUNK        STRAIN SPRAIN  TREATED AND RELEASED
# 359122               EAR           LACERATION  TREATED AND RELEASED
# 359123              HEAD      INTERNAL INJURY  TREATED AND RELEASED
# 359124              HEAD      INTERNAL INJURY  TREATED AND RELEASED
# 359125              FACE           LACERATION  TREATED AND RELEASED
# 359126    ALL PARTS BODY            POISONING  TREATED AND RELEASED
# 359127       LOWER TRUNK                OTHER  TREATED AND RELEASED
# 359128              HAND           LACERATION  TREATED AND RELEASED
# 359129             WRIST             FRACTURE  TREATED AND RELEASED
#
#                           fire_descrip locale_descrip  \
# 1                              NO FIRE         SPORTS
# 2                              NO FIRE           HOME
# 3                              NO FIRE        UNKNOWN
# 4                              NO FIRE        UNKNOWN
# 5                              NO FIRE        UNKNOWN
# 6                              NO FIRE           HOME
# 7       UNKNOWN IF FIRE DEPT. ATTENDED         SPORTS
# 8                              NO FIRE        UNKNOWN
# 9                              NO FIRE           HOME
# 10                             NO FIRE         PUBLIC
# 11                             NO FIRE           HOME
# 12                             NO FIRE         SPORTS
# 13                             NO FIRE        UNKNOWN
# 14                             NO FIRE           HOME
# 15                             NO FIRE           HOME
# 16                             NO FIRE        UNKNOWN
# 17                             NO FIRE           HOME
# 18                             NO FIRE           HOME
# 19                             NO FIRE           HOME
# 20                             NO FIRE           HOME
# 21                             NO FIRE        UNKNOWN
# 22                             NO FIRE           HOME
# 23                             NO FIRE        UNKNOWN
# 24                             NO FIRE        UNKNOWN
# 25                             NO FIRE           HOME
# 26                             NO FIRE        UNKNOWN
# 27                             NO FIRE        UNKNOWN
# 28                             NO FIRE        UNKNOWN
# 29                             NO FIRE           HOME
# 30                             NO FIRE        UNKNOWN
# ...                                ...            ...
# 359100                         NO FIRE         SPORTS
# 359101                         NO FIRE        UNKNOWN
# 359102                         NO FIRE           HOME
# 359103                         NO FIRE           HOME
# 359104                         NO FIRE           HOME
# 359105                         NO FIRE         SPORTS
# 359106                         NO FIRE           HOME
# 359107                         NO FIRE           HOME
# 359108                         NO FIRE        UNKNOWN
# 359109                         NO FIRE           HOME
# 359110                         NO FIRE           HOME
# 359111                         NO FIRE           HOME
# 359112                         NO FIRE           HOME
# 359113                         NO FIRE         SPORTS
# 359114                         NO FIRE           HOME
# 359115                         NO FIRE           HOME
# 359116                         NO FIRE        UNKNOWN
# 359117                         NO FIRE           HOME
# 359118                         NO FIRE        UNKNOWN
# 359119                         NO FIRE        UNKNOWN
# 359120                         NO FIRE           HOME
# 359121                         NO FIRE           HOME
# 359122                         NO FIRE        UNKNOWN
# 359123                         NO FIRE         PUBLIC
# 359124                         NO FIRE           HOME
# 359125                         NO FIRE           HOME
# 359126                         NO FIRE        UNKNOWN
# 359127                         NO FIRE        UNKNOWN
# 359128                         NO FIRE           HOME
# 359129                         NO FIRE         SPORTS
#
#                                          product1_descrip  \
# 1               "SOCCER (ACTIVITY, APPAREL OR EQUIPMENT)"
# 2                            "LAWN MOWERS, NOT SPECIFIED"
# 3             "SWIMMING (ACTIVITY, APPAREL OR EQUIPMENT)"
# 4                                     BATHTUBS OR SHOWERS
# 5              "DOORS, OTHER OR NOT SPECIFIED           "
# 6                                            PET SUPPLIES
# 7                     PRESSURIZED CONTAINERS (NONAEROSOL)
# 8       "BICYCLES AND ACCESSORIES, (EXCL.MOUNTAIN OR A...
# 9                            FLOORS OR FLOORING MATERIALS
# 10      "TABLES (EXCL.  BABY CHANGING TABLES, BILLIARD...
# 11             "WINDOWS & WINDOW GLASS, EXCL STORM WINDO"
# 12              "SOCCER (ACTIVITY, APPAREL OR EQUIPMENT)"
# 13            "SWIMMING (ACTIVITY, APPAREL OR EQUIPMENT)"
# 14                           FLOORS OR FLOORING MATERIALS
# 15      "TABLES (EXCL.  BABY CHANGING TABLES, BILLIARD...
# 16                                               HACKSAWS
# 17      "PORCHES, BALCONIES, OPEN-SIDE FLOORS OR FLOOR...
# 18                                                   FANS
# 19                             "FURNITURE, NOT SPECIFIED"
# 20                              TABLEWARE AND ACCESSORIES
# 21                       "RUGS OR CARPETS, NOT SPECIFIED"
# 22      "TWO-WHEELED, POWERED, OFF-ROAD VEHICLES (INCL...
# 23      "HORSEBACK RIDING (ACTIVITY, APPAREL OR EQUIPM...
# 24                                  "SCOOTERS, UNPOWERED"
# 25                                    BATHTUBS OR SHOWERS
# 26      "SOFAS, COUCHES, DAVENPORTS, DIVANS OR STUDIO ...
# 27       CEILINGS AND WALLS (PART OF COMPLETED STRUCTURE)
# 28            "SWIMMING (ACTIVITY, APPAREL OR EQUIPMENT)"
# 29             "BEDS OR BEDFRAMES, OTHER OR NOT SPEC    "
# 30            "FOOTBALL (ACTIVITY, APPAREL OR EQUIPMENT)"
# ...                                                   ...
# 359100                        FLYING DISCS AND BOOMERANGS
# 359101                                            JEWELRY
# 359102                                   HATCHETS OR AXES
# 359103         "BEDS OR BEDFRAMES, OTHER OR NOT SPEC    "
# 359104                         "FURNITURE, NOT SPECIFIED"
# 359105                                        TRAMPOLINES
# 359106                       FLOORS OR FLOORING MATERIALS
# 359107                            SWIMMING POOL EQUIPMENT
# 359108   ALL TERRAIN VEHICLES (FOUR WHEELS/OFF ROAD ONLY)
# 359109                              FENCES OR FENCE POSTS
# 359110                   "RUGS OR CARPETS, NOT SPECIFIED"
# 359111                 "KNIVES, NOT ELSEWHERE CLASSIFIED"
# 359112                     KNIVES WITH REPLACEABLE BLADES
# 359113       "BASKETBALL, ACTIVITY AND RELATED EQUIPMENT"
# 359114         "BEDS OR BEDFRAMES, OTHER OR NOT SPEC    "
# 359115                       FLOORS OR FLOORING MATERIALS
# 359116                                     BBS OR PELLETS
# 359117                                    STAIRS OR STEPS
# 359118  "ROLLER SKATING (ACTIVITY, APPAREL OR EQUIPMENT)"
# 359119  "COSMETICS, INCL FACIAL & EYE MAKE-UP, DEODORA...
# 359120                                            JEWELRY
# 359121                                     BABY STROLLERS
# 359122                                            JEWELRY
# 359123                       FLOORS OR FLOORING MATERIALS
# 359124                                          TRICYCLES
# 359125                            COUNTERS OR COUNTERTOPS
# 359126                            TABLET OR CAPSULE DRUGS
# 359127                  PORTABLE FOOD OR BEVERAGE COOLERS
# 359128                 "KNIVES, NOT ELSEWHERE CLASSIFIED"
# 359129              "PLAYGROUND EQUIPMENT, NOT SPECIFIED"
#
#                                          product2_descrip  \
# 1                                                     NaN
# 2       "TABLES (EXCL.  BABY CHANGING TABLES, BILLIARD...
# 3                                                     NaN
# 4                                                     NaN
# 5                            FLOORS OR FLOORING MATERIALS
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                           FLOORS OR FLOORING MATERIALS
# 11                                                    NaN
# 12                                                    NaN
# 13                        "SWIMMING POOLS, NOT SPECIFIED"
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                           FLOORS OR FLOORING MATERIALS
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# 30                                                    NaN
# ...                                                   ...
# 359100                                                NaN
# 359101                                                NaN
# 359102                                                NaN
# 359103                                                NaN
# 359104                                                NaN
# 359105                                                NaN
# 359106                                                NaN
# 359107                                                NaN
# 359108                                                NaN
# 359109                                                NaN
# 359110   CEILINGS AND WALLS (PART OF COMPLETED STRUCTURE)
# 359111                                                NaN
# 359112                                                NaN
# 359113                                                NaN
# 359114                       FLOORS OR FLOORING MATERIALS
# 359115                                                NaN
# 359116                                                NaN
# 359117                                                NaN
# 359118                                                NaN
# 359119                                                NaN
# 359120                                                NaN
# 359121                                                NaN
# 359122                                                NaN
# 359123                                                NaN
# 359124                                                NaN
# 359125                                                NaN
# 359126                                                NaN
# 359127                                                NaN
# 359128                                                NaN
# 359129                                                NaN
#
#                                                     Notes
# 1       5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 2       L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 3       20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 4                                                     NaN
# 5       88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
# 6       16 MOF AT HOME PULLED FAMILY DOG-HUSKIES COLLA...
# 7       25 YOM WAS CAMPING WHEN FRIEND THREW A PRESSUR...
# 8                                                     NaN
# 9                                                     NaN
# 10      48 YO F, C/O RT FLANK PAIN 6 DAYS S/P FALL WAS...
# 11                                                    NaN
# 12      L DISTAL FIB FX/20YOWF WHILE PLAYING SOCCER AT...
# 13      DX LOSS TEETH D/T TRAUME: 11YOM LOOSE LOWER R ...
# 14                                                    NaN
# 15      33 YOM SMASHED FOOT INTO COFFEE TABLE LAST PM....
# 16      36 YOM CUT HAND WITH A HACKSAWDX:  HAND LACERA...
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20      4 M/.O F   BROTHER  DROPPED  CUP  ON FACELAC  ...
# 21                                                    NaN
# 22      16 YOM TRIED TO DO A WHEELIE ON HIS DIRT BIKE ...
# 23      31 YOM WAS THROWN FROM A HORSE INTO A TREE AND...
# 24                                                    NaN
# 25                                                    NaN
# 26      9 MO F AT 11:30AM TODAY FELL APPROX 2 FT FT BA...
# 27      27 YO F C/O LT 5TH TOE PAIN REPORTS STUBBING T...
# 28      39YOM DOING ALOT OF SWIMMING AND NOW EARS HURT...
# 29                                                    NaN
# 30      14YOM PAIN TO BACK AND HEAD WHEN PLAYING FOOTB...
# ...                                                   ...
# 359100                                                NaN
# 359101                                                NaN
# 359102  51YF ACC STRUCK FOOT C AN AXE HANDLE WHILE HEL...
# 359103                                                NaN
# 359104  21 YOF C/O LOW BACK PAIN AFTER HELPING MOVE HE...
# 359105                                                NaN
# 359106                                                NaN
# 359107                                                NaN
# 359108                                                NaN
# 359109  5 YOF MOTHER STATES CHILD RAN INTO A FENCE AT ...
# 359110                                                NaN
# 359111  12YF ACC CUT FINGER ON A KNIFE CUTTING ICECREA...
# 359112                                                NaN
# 359113                                                NaN
# 359114  1MOM-PT & 5YOLD SIBLING WERE LAYING ON THE BED...
# 359115  18 MOM PLAYING WITH BROTHER THIS A.M. AND FELL...
# 359116                                                NaN
# 359117  RT SHOULDER STR.  52YOF FELL GOING DOWN A FLIG...
# 359118  DX ELBOW STRAIN R: 8YOF FELL YTDY W ROLLER SKA...
# 359119  20 MOF TOXIC INGESTION, MOM REPORTS WITNESSING...
# 359120                                                NaN
# 359121  LUMBAR STRAIN. 30 YOF STRAINED HER LOWER BACK ...
# 359122  15 MOF R EARRING WAS PULLED OUT OF EAR RESULTI...
# 359123  14YOF AT THE HOSPITAL WAS WITNESSING HER SISTE...
# 359124                                                NaN
# 359125                                                NaN
# 359126                                                NaN
# 359127  38YM C/O WORSENING LBP THAT STARTED WHILE LIFT...
# 359128  38 YOF INJURED HAND, CUT WITH BREAD KNIFE AT H...
# 359129  5YOF ON A PLAYGROUND & FELL OFF PLAY STRUCTURE...
#
# [359129 rows x 15 columns]
